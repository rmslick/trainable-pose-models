# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.applications import VGG16
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input
from tensorflow.keras.applications import MobileNetV2

def create_6DoF_model_quaternion(input_shape=(224, 224, 3)):
    base_model = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)

    # Predicting a quaternion (4 values) for rotation and a 3D vector for translation.
    pose_output = Dense(7, name='6DoF_output')(x)

    model = Model(inputs=base_model.input, outputs=pose_output)
    return model

# %%
from keras.applications.resnet50 import ResNet50
from keras.layers import GlobalAveragePooling2D, Dense, Concatenate

def create_resnet_6dof_model(input_shape=(224, 224, 3)):
    # Load the ResNet50 model with weights pre-trained on ImageNet
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the layers of the ResNet model
    for layer in base_model.layers:
        layer.trainable = False

    # Extract features using the ResNet50 model
    x = base_model.output

    # Add some custom layers on top
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu')(x)

    # Predict the 3 translation values
    translation = Dense(3, name="translation")(x)

    # Predict the 4 quaternion values for rotation
    quaternion = Dense(4, activation='tanh', name="quaternion")(x)

    # Combine the translation and rotation into a single output
    final_output = Concatenate(name="6DoF_output")([translation, quaternion])

    # Construct the full model
    model = Model(inputs=base_model.input, outputs=final_output)

    return model

# %%
import os
import json
import cv2
import numpy as np

def load_images_from_folder(folder_path, img_size=(224, 224)):
    """Load images from a folder and resize them."""

    images = []
    image_names = sorted(os.listdir(folder_path))

    for image_name in image_names:
        img_path = os.path.join(folder_path, image_name)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, img_size)
        images.append(img)

    return images

def load_json(file_path):
    """Load a JSON file."""

    with open(file_path, 'r') as f:
        data = json.load(f)

    return data
def process_gt_data(scene_gt, scene_camera):
    """Extract 6DoF pose and camera parameters from scene_gt and scene_camera."""

    poses = []
    camera_params = []

    for image_id, annotations in scene_gt.items():
        image_data = []
        for annotation in annotations:
            R = np.array(annotation["cam_R_m2c"]).reshape(3, 3)
            t = np.array(annotation["cam_t_m2c"]).reshape(3, 1)
            pose = np.hstack([R, t])
            image_data.append(pose)
        poses.append(image_data)

        cam_data = scene_camera[image_id]
        K = np.array(cam_data["cam_K"]).reshape(3, 3)
        camera_params.append(K)

    return poses, camera_params
from tensorflow.keras.preprocessing import image

def preprocess_images(images):
    """Normalize the images to [0, 1]."""
    return np.array(images, dtype=np.float32) / 255.0
# !wget https://bop.felk.cvut.cz/media/data/bop_datasets/lm_test_all.zip
#!mkdir /content/drive/MyDrive/trainable_pose
#!mv /content/lm_test_all.zip /content/drive/MyDrive/trainable_pose/
# !unzip lm_test_all.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/000014/mask_visib/001220_000000.png
#   inflating: test/000014/rgb/001221.png
#   inflating: test/000014/depth/001221.png
#   inflating: test/000014/mask/001221_000000.png
#   inflating: test/000014/mask_visib/001221_000000.png
#   inflating: test/000014/rgb/001222.png
#   inflating: test/000014/depth/001222.png
#   inflating: test/000014/mask/001222_000000.png
#   inflating: test/000014/mask_visib/001222_000000.png
#   inflating: test/000014/rgb/001223.png
#   inflating: test/000014/depth/001223.png
#   inflating: test/000014/mask/001223_000000.png
#   inflating: test/000014/mask_visib/001223_000000.png
#   inflating: test/000014/rgb/001224.png
#   inflating: test/000014/depth/001224.png
#   inflating: test/000014/mask/001224_000000.png
#   inflating: test/000014/mask_visib/001224_000000.png
#   inflating: test/000014/rgb/001225.png
#   inflating: test/000014/depth/001225.png
#   inflating: test/000014/mask/001225_000000.png
#   inflating: test/000014/mask_visib/001225_000000.png
#   inflating: test/000014/rgb/001226.png
#   inflating: test/000014/depth/001226.png
#   inflating: test/000014/mask/001226_000000.png
#   inflating: test/000014/mask_visib/001226_000000.png
#   inflating: test/000015/scene_camera.json
#   inflating: test/000015/scene_gt.json
#   inflating: test/000015/scene_gt_info.json
#   inflating: test/000015/rgb/000000.png
#   inflating: test/000015/depth/000000.png
#   inflating: test/000015/mask/000000_000000.png
#   inflating: test/000015/mask_visib/000000_000000.png
#   inflating: test/000015/rgb/000001.png
#   inflating: test/000015/depth/000001.png
#   inflating: test/000015/mask/000001_000000.png
#   inflating: test/000015/mask_visib/000001_000000.png
#   inflating: test/000015/rgb/000002.png
#   inflating: test/000015/depth/000002.png
#   inflating: test/000015/mask/000002_000000.png
#   inflating: test/000015/mask_visib/000002_000000.png
#   inflating: test/000015/rgb/000003.png
#   inflating: test/000015/depth/000003.png
#   inflating: test/000015/mask/000003_000000.png
#   inflating: test/000015/mask_visib/000003_000000.png
#   inflating: test/000015/rgb/000004.png
#   inflating: test/000015/depth/000004.png
#   inflating: test/000015/mask/000004_000000.png
#   inflating: test/000015/mask_visib/000004_000000.png
#   inflating: test/000015/rgb/000005.png
#   inflating: test/000015/depth/000005.png
#   inflating: test/000015/mask/000005_000000.png
#   inflating: test/000015/mask_visib/000005_000000.png
#   inflating: test/000015/rgb/000006.png
#   inflating: test/000015/depth/000006.png
#   inflating: test/000015/mask/000006_000000.png
#   inflating: test/000015/mask_visib/000006_000000.png
#   inflating: test/000015/rgb/000007.png
#   inflating: test/000015/depth/000007.png
#   inflating: test/000015/mask/000007_000000.png
#   inflating: test/000015/mask_visib/000007_000000.png
#   inflating: test/000015/rgb/000008.png
#   inflating: test/000015/depth/000008.png
#   inflating: test/000015/mask/000008_000000.png
#   inflating: test/000015/mask_visib/000008_000000.png
#   inflating: test/000015/rgb/000009.png
#   inflating: test/000015/depth/000009.png
#   inflating: test/000015/mask/000009_000000.png
#   inflating: test/000015/mask_visib/000009_000000.png
#   inflating: test/000015/rgb/000010.png
#   inflating: test/000015/depth/000010.png
#   inflating: test/000015/mask/000010_000000.png
#   inflating: test/000015/mask_visib/000010_000000.png
#   inflating: test/000015/rgb/000011.png
#   inflating: test/000015/depth/000011.png
#   inflating: test/000015/mask/000011_000000.png
#   inflating: test/000015/mask_visib/000011_000000.png
#   inflating: test/000015/rgb/000012.png
#   inflating: test/000015/depth/000012.png
#   inflating: test/000015/mask/000012_000000.png
#   inflating: test/000015/mask_visib/000012_000000.png
#   inflating: test/000015/rgb/000013.png
#   inflating: test/000015/depth/000013.png
#   inflating: test/000015/mask/000013_000000.png
#   inflating: test/000015/mask_visib/000013_000000.png
#   inflating: test/000015/rgb/000014.png
#   inflating: test/000015/depth/000014.png
#   inflating: test/000015/mask/000014_000000.png
#   inflating: test/000015/mask_visib/000014_000000.png
#   inflating: test/000015/rgb/000015.png
#   inflating: test/000015/depth/000015.png
#   inflating: test/000015/mask/000015_000000.png
#   inflating: test/000015/mask_visib/000015_000000.png
#   inflating: test/000015/rgb/000016.png
#   inflating: test/000015/depth/000016.png
#   inflating: test/000015/mask/000016_000000.png
#   inflating: test/000015/mask_visib/000016_000000.png
#   inflating: test/000015/rgb/000017.png
#   inflating: test/000015/depth/000017.png
#   inflating: test/000015/mask/000017_000000.png
#   inflating: test/000015/mask_visib/000017_000000.png
#   inflating: test/000015/rgb/000018.png
#   inflating: test/000015/depth/000018.png
#   inflating: test/000015/mask/000018_000000.png
#   inflating: test/000015/mask_visib/000018_000000.png
#   inflating: test/000015/rgb/000019.png
#   inflating: test/000015/depth/000019.png
#   inflating: test/000015/mask/000019_000000.png
#   inflating: test/000015/mask_visib/000019_000000.png
#   inflating: test/000015/rgb/000020.png
#   inflating: test/000015/depth/000020.png
#   inflating: test/000015/mask/000020_000000.png
#   inflating: test/000015/mask_visib/000020_000000.png
#   inflating: test/000015/rgb/000021.png
#   inflating: test/000015/depth/000021.png
#   inflating: test/000015/mask/000021_000000.png
#   inflating: test/000015/mask_visib/000021_000000.png
#   inflating: test/000015/rgb/000022.png
#   inflating: test/000015/depth/000022.png
#   inflating: test/000015/mask/000022_000000.png
#   inflating: test/000015/mask_visib/000022_000000.png
#   inflating: test/000015/rgb/000023.png
#   inflating: test/000015/depth/000023.png
#   inflating: test/000015/mask/000023_000000.png
#   inflating: test/000015/mask_visib/000023_000000.png
#   inflating: test/000015/rgb/000024.png
#   inflating: test/000015/depth/000024.png
#   inflating: test/000015/mask/000024_000000.png
#   inflating: test/000015/mask_visib/000024_000000.png
#   inflating: test/000015/rgb/000025.png
#   inflating: test/000015/depth/000025.png
#   inflating: test/000015/mask/000025_000000.png
#   inflating: test/000015/mask_visib/000025_000000.png
#   inflating: test/000015/rgb/000026.png
#   inflating: test/000015/depth/000026.png
#   inflating: test/000015/mask/000026_000000.png
#   inflating: test/000015/mask_visib/000026_000000.png
#   inflating: test/000015/rgb/000027.png
#   inflating: test/000015/depth/000027.png
#   inflating: test/000015/mask/000027_000000.png
#   inflating: test/000015/mask_visib/000027_000000.png
#   inflating: test/000015/rgb/000028.png
#   inflating: test/000015/depth/000028.png
#   inflating: test/000015/mask/000028_000000.png
#   inflating: test/000015/mask_visib/000028_000000.png
#   inflating: test/000015/rgb/000029.png
#   inflating: test/000015/depth/000029.png
#   inflating: test/000015/mask/000029_000000.png
#   inflating: test/000015/mask_visib/000029_000000.png
#   inflating: test/000015/rgb/000030.png
#   inflating: test/000015/depth/000030.png
#   inflating: test/000015/mask/000030_000000.png
#   inflating: test/000015/mask_visib/000030_000000.png
#   inflating: test/000015/rgb/000031.png
#   inflating: test/000015/depth/000031.png
#   inflating: test/000015/mask/000031_000000.png
#   inflating: test/000015/mask_visib/000031_000000.png
#   inflating: test/000015/rgb/000032.png
#   inflating: test/000015/depth/000032.png
#   inflating: test/000015/mask/000032_000000.png
#   inflating: test/000015/mask_visib/000032_000000.png
#   inflating: test/000015/rgb/000033.png
#   inflating: test/000015/depth/000033.png
#   inflating: test/000015/mask/000033_000000.png
#   inflating: test/000015/mask_visib/000033_000000.png
#   inflating: test/000015/rgb/000034.png
#   inflating: test/000015/depth/000034.png
#   inflating: test/000015/mask/000034_000000.png
#   inflating: test/000015/mask_visib/000034_000000.png
#   inflating: test/000015/rgb/000035.png
#   inflating: test/000015/depth/000035.png
#   inflating: test/000015/mask/000035_000000.png
#   inflating: test/000015/mask_visib/000035_000000.png
#   inflating: test/000015/rgb/000036.png
#   inflating: test/000015/depth/000036.png
#   inflating: test/000015/mask/000036_000000.png
#   inflating: test/000015/mask_visib/000036_000000.png
#   inflating: test/000015/rgb/000037.png
#   inflating: test/000015/depth/000037.png
#   inflating: test/000015/mask/000037_000000.png
#   inflating: test/000015/mask_visib/000037_000000.png
#   inflating: test/000015/rgb/000038.png
#   inflating: test/000015/depth/000038.png
#   inflating: test/000015/mask/000038_000000.png
#   inflating: test/000015/mask_visib/000038_000000.png
#   inflating: test/000015/rgb/000039.png
#   inflating: test/000015/depth/000039.png
#   inflating: test/000015/mask/000039_000000.png
#   inflating: test/000015/mask_visib/000039_000000.png
#   inflating: test/000015/rgb/000040.png
#   inflating: test/000015/depth/000040.png
#   inflating: test/000015/mask/000040_000000.png
#   inflating: test/000015/mask_visib/000040_000000.png
#   inflating: test/000015/rgb/000041.png
#   inflating: test/000015/depth/000041.png
#   inflating: test/000015/mask/000041_000000.png
#   inflating: test/000015/mask_visib/000041_000000.png
#   inflating: test/000015/rgb/000042.png
#   inflating: test/000015/depth/000042.png
#   inflating: test/000015/mask/000042_000000.png
#   inflating: test/000015/mask_visib/000042_000000.png
#   inflating: test/000015/rgb/000043.png
#   inflating: test/000015/depth/000043.png
#   inflating: test/000015/mask/000043_000000.png
#   inflating: test/000015/mask_visib/000043_000000.png
#   inflating: test/000015/rgb/000044.png
#   inflating: test/000015/depth/000044.png
#   inflating: test/000015/mask/000044_000000.png
#   inflating: test/000015/mask_visib/000044_000000.png
#   inflating: test/000015/rgb/000045.png
#   inflating: test/000015/depth/000045.png
#   inflating: test/000015/mask/000045_000000.png
#   inflating: test/000015/mask_visib/000045_000000.png
#   inflating: test/000015/rgb/000046.png
#   inflating: test/000015/depth/000046.png
#   inflating: test/000015/mask/000046_000000.png
#   inflating: test/000015/mask_visib/000046_000000.png
#   inflating: test/000015/rgb/000047.png
#   inflating: test/000015/depth/000047.png
#   inflating: test/000015/mask/000047_000000.png
#   inflating: test/000015/mask_visib/000047_000000.png
#   inflating: test/000015/rgb/000048.png
#   inflating: test/000015/depth/000048.png
#   inflating: test/000015/mask/000048_000000.png
#   inflating: test/000015/mask_visib/000048_000000.png
#   inflating: test/000015/rgb/000049.png
#   inflating: test/000015/depth/000049.png
#   inflating: test/000015/mask/000049_000000.png
#   inflating: test/000015/mask_visib/000049_000000.png
#   inflating: test/000015/rgb/000050.png
#   inflating: test/000015/depth/000050.png
#   inflating: test/000015/mask/000050_000000.png
#   inflating: test/000015/mask_visib/000050_000000.png
#   inflating: test/000015/rgb/000051.png
#   inflating: test/000015/depth/000051.png
#   inflating: test/000015/mask/000051_000000.png
#   inflating: test/000015/mask_visib/000051_000000.png
#   inflating: test/000015/rgb/000052.png
#   inflating: test/000015/depth/000052.png
#   inflating: test/000015/mask/000052_000000.png
#   inflating: test/000015/mask_visib/000052_000000.png
#   inflating: test/000015/rgb/000053.png
#   inflating: test/000015/depth/000053.png
#   inflating: test/000015/mask/000053_000000.png
#   inflating: test/000015/mask_visib/000053_000000.png
#   inflating: test/000015/rgb/000054.png
#   inflating: test/000015/depth/000054.png
#   inflating: test/000015/mask/000054_000000.png
#   inflating: test/000015/mask_visib/000054_000000.png
#   inflating: test/000015/rgb/000055.png
#   inflating: test/000015/depth/000055.png
#   inflating: test/000015/mask/000055_000000.png
#   inflating: test/000015/mask_visib/000055_000000.png
#   inflating: test/000015/rgb/000056.png
#   inflating: test/000015/depth/000056.png
#   inflating: test/000015/mask/000056_000000.png
#   inflating: test/000015/mask_visib/000056_000000.png
#   inflating: test/000015/rgb/000057.png
#   inflating: test/000015/depth/000057.png
#   inflating: test/000015/mask/000057_000000.png
#   inflating: test/000015/mask_visib/000057_000000.png
#   inflating: test/000015/rgb/000058.png
#   inflating: test/000015/depth/000058.png
#   inflating: test/000015/mask/000058_000000.png
#   inflating: test/000015/mask_visib/000058_000000.png
#   inflating: test/000015/rgb/000059.png
#   inflating: test/000015/depth/000059.png
#   inflating: test/000015/mask/000059_000000.png
#   inflating: test/000015/mask_visib/000059_000000.png
#   inflating: test/000015/rgb/000060.png
#   inflating: test/000015/depth/000060.png
#   inflating: test/000015/mask/000060_000000.png
#   inflating: test/000015/mask_visib/000060_000000.png
#   inflating: test/000015/rgb/000061.png
#   inflating: test/000015/depth/000061.png
#   inflating: test/000015/mask/000061_000000.png
#   inflating: test/000015/mask_visib/000061_000000.png
#   inflating: test/000015/rgb/000062.png
#   inflating: test/000015/depth/000062.png
#   inflating: test/000015/mask/000062_000000.png
#   inflating: test/000015/mask_visib/000062_000000.png
#   inflating: test/000015/rgb/000063.png
#   inflating: test/000015/depth/000063.png
#   inflating: test/000015/mask/000063_000000.png
#   inflating: test/000015/mask_visib/000063_000000.png
#   inflating: test/000015/rgb/000064.png
#   inflating: test/000015/depth/000064.png
#   inflating: test/000015/mask/000064_000000.png
#   inflating: test/000015/mask_visib/000064_000000.png
#   inflating: test/000015/rgb/000065.png
#   inflating: test/000015/depth/000065.png
#   inflating: test/000015/mask/000065_000000.png
#   inflating: test/000015/mask_visib/000065_000000.png
#   inflating: test/000015/rgb/000066.png
#   inflating: test/000015/depth/000066.png
#   inflating: test/000015/mask/000066_000000.png
#   inflating: test/000015/mask_visib/000066_000000.png
#   inflating: test/000015/rgb/000067.png
#   inflating: test/000015/depth/000067.png
#   inflating: test/000015/mask/000067_000000.png
#   inflating: test/000015/mask_visib/000067_000000.png
#   inflating: test/000015/rgb/000068.png
#   inflating: test/000015/depth/000068.png
#   inflating: test/000015/mask/000068_000000.png
#   inflating: test/000015/mask_visib/000068_000000.png
#   inflating: test/000015/rgb/000069.png
#   inflating: test/000015/depth/000069.png
#   inflating: test/000015/mask/000069_000000.png
#   inflating: test/000015/mask_visib/000069_000000.png
#   inflating: test/000015/rgb/000070.png
#   inflating: test/000015/depth/000070.png
#   inflating: test/000015/mask/000070_000000.png
#   inflating: test/000015/mask_visib/000070_000000.png
#   inflating: test/000015/rgb/000071.png
#   inflating: test/000015/depth/000071.png
#   inflating: test/000015/mask/000071_000000.png
#   inflating: test/000015/mask_visib/000071_000000.png
#   inflating: test/000015/rgb/000072.png
#   inflating: test/000015/depth/000072.png
#   inflating: test/000015/mask/000072_000000.png
#   inflating: test/000015/mask_visib/000072_000000.png
#   inflating: test/000015/rgb/000073.png
#   inflating: test/000015/depth/000073.png
#   inflating: test/000015/mask/000073_000000.png
#   inflating: test/000015/mask_visib/000073_000000.png
#   inflating: test/000015/rgb/000074.png
#   inflating: test/000015/depth/000074.png
#   inflating: test/000015/mask/000074_000000.png
#   inflating: test/000015/mask_visib/000074_000000.png
#   inflating: test/000015/rgb/000075.png
#   inflating: test/000015/depth/000075.png
#   inflating: test/000015/mask/000075_000000.png
#   inflating: test/000015/mask_visib/000075_000000.png
#   inflating: test/000015/rgb/000076.png
#   inflating: test/000015/depth/000076.png
#   inflating: test/000015/mask/000076_000000.png
#   inflating: test/000015/mask_visib/000076_000000.png
#   inflating: test/000015/rgb/000077.png
#   inflating: test/000015/depth/000077.png
#   inflating: test/000015/mask/000077_000000.png
#   inflating: test/000015/mask_visib/000077_000000.png
#   inflating: test/000015/rgb/000078.png
#   inflating: test/000015/depth/000078.png
#   inflating: test/000015/mask/000078_000000.png
#   inflating: test/000015/mask_visib/000078_000000.png
#   inflating: test/000015/rgb/000079.png
#   inflating: test/000015/depth/000079.png
#   inflating: test/000015/mask/000079_000000.png
#   inflating: test/000015/mask_visib/000079_000000.png
#   inflating: test/000015/rgb/000080.png
#   inflating: test/000015/depth/000080.png
#   inflating: test/000015/mask/000080_000000.png
#   inflating: test/000015/mask_visib/000080_000000.png
#   inflating: test/000015/rgb/000081.png
#   inflating: test/000015/depth/000081.png
#   inflating: test/000015/mask/000081_000000.png
#   inflating: test/000015/mask_visib/000081_000000.png
#   inflating: test/000015/rgb/000082.png
#   inflating: test/000015/depth/000082.png
#   inflating: test/000015/mask/000082_000000.png
#   inflating: test/000015/mask_visib/000082_000000.png
#   inflating: test/000015/rgb/000083.png
#   inflating: test/000015/depth/000083.png
#   inflating: test/000015/mask/000083_000000.png
#   inflating: test/000015/mask_visib/000083_000000.png
#   inflating: test/000015/rgb/000084.png
#   inflating: test/000015/depth/000084.png
#   inflating: test/000015/mask/000084_000000.png
#   inflating: test/000015/mask_visib/000084_000000.png
#   inflating: test/000015/rgb/000085.png
#   inflating: test/000015/depth/000085.png
#   inflating: test/000015/mask/000085_000000.png
#   inflating: test/000015/mask_visib/000085_000000.png
#   inflating: test/000015/rgb/000086.png
#   inflating: test/000015/depth/000086.png
#   inflating: test/000015/mask/000086_000000.png
#   inflating: test/000015/mask_visib/000086_000000.png
#   inflating: test/000015/rgb/000087.png
#   inflating: test/000015/depth/000087.png
#   inflating: test/000015/mask/000087_000000.png
#   inflating: test/000015/mask_visib/000087_000000.png
#   inflating: test/000015/rgb/000088.png
#   inflating: test/000015/depth/000088.png
#   inflating: test/000015/mask/000088_000000.png
#   inflating: test/000015/mask_visib/000088_000000.png
#   inflating: test/000015/rgb/000089.png
#   inflating: test/000015/depth/000089.png
#   inflating: test/000015/mask/000089_000000.png
#   inflating: test/000015/mask_visib/000089_000000.png
#   inflating: test/000015/rgb/000090.png
#   inflating: test/000015/depth/000090.png
#   inflating: test/000015/mask/000090_000000.png
#   inflating: test/000015/mask_visib/000090_000000.png
#   inflating: test/000015/rgb/000091.png
#   inflating: test/000015/depth/000091.png
#   inflating: test/000015/mask/000091_000000.png
#   inflating: test/000015/mask_visib/000091_000000.png
#   inflating: test/000015/rgb/000092.png
#   inflating: test/000015/depth/000092.png
#   inflating: test/000015/mask/000092_000000.png
#   inflating: test/000015/mask_visib/000092_000000.png
#   inflating: test/000015/rgb/000093.png
#   inflating: test/000015/depth/000093.png
#   inflating: test/000015/mask/000093_000000.png
#   inflating: test/000015/mask_visib/000093_000000.png
#   inflating: test/000015/rgb/000094.png
#   inflating: test/000015/depth/000094.png
#   inflating: test/000015/mask/000094_000000.png
#   inflating: test/000015/mask_visib/000094_000000.png
#   inflating: test/000015/rgb/000095.png
#   inflating: test/000015/depth/000095.png
#   inflating: test/000015/mask/000095_000000.png
#   inflating: test/000015/mask_visib/000095_000000.png
#   inflating: test/000015/rgb/000096.png
#   inflating: test/000015/depth/000096.png
#   inflating: test/000015/mask/000096_000000.png
#   inflating: test/000015/mask_visib/000096_000000.png
#   inflating: test/000015/rgb/000097.png
#   inflating: test/000015/depth/000097.png
#   inflating: test/000015/mask/000097_000000.png
#   inflating: test/000015/mask_visib/000097_000000.png
#   inflating: test/000015/rgb/000098.png
#   inflating: test/000015/depth/000098.png
#   inflating: test/000015/mask/000098_000000.png
#   inflating: test/000015/mask_visib/000098_000000.png
#   inflating: test/000015/rgb/000099.png
#   inflating: test/000015/depth/000099.png
#   inflating: test/000015/mask/000099_000000.png
#   inflating: test/000015/mask_visib/000099_000000.png
#   inflating: test/000015/rgb/000100.png
#   inflating: test/000015/depth/000100.png
#   inflating: test/000015/mask/000100_000000.png
#   inflating: test/000015/mask_visib/000100_000000.png
#   inflating: test/000015/rgb/000101.png
#   inflating: test/000015/depth/000101.png
#   inflating: test/000015/mask/000101_000000.png
#   inflating: test/000015/mask_visib/000101_000000.png
#   inflating: test/000015/rgb/000102.png
#   inflating: test/000015/depth/000102.png
#   inflating: test/000015/mask/000102_000000.png
#   inflating: test/000015/mask_visib/000102_000000.png
#   inflating: test/000015/rgb/000103.png
#   inflating: test/000015/depth/000103.png
#   inflating: test/000015/mask/000103_000000.png
#   inflating: test/000015/mask_visib/000103_000000.png
#   inflating: test/000015/rgb/000104.png
#   inflating: test/000015/depth/000104.png
#   inflating: test/000015/mask/000104_000000.png
#   inflating: test/000015/mask_visib/000104_000000.png
#   inflating: test/000015/rgb/000105.png
#   inflating: test/000015/depth/000105.png
#   inflating: test/000015/mask/000105_000000.png
#   inflating: test/000015/mask_visib/000105_000000.png
#   inflating: test/000015/rgb/000106.png
#   inflating: test/000015/depth/000106.png
#   inflating: test/000015/mask/000106_000000.png
#   inflating: test/000015/mask_visib/000106_000000.png
#   inflating: test/000015/rgb/000107.png
#   inflating: test/000015/depth/000107.png
#   inflating: test/000015/mask/000107_000000.png
#   inflating: test/000015/mask_visib/000107_000000.png
#   inflating: test/000015/rgb/000108.png
#   inflating: test/000015/depth/000108.png
#   inflating: test/000015/mask/000108_000000.png
#   inflating: test/000015/mask_visib/000108_000000.png
#   inflating: test/000015/rgb/000109.png
#   inflating: test/000015/depth/000109.png
#   inflating: test/000015/mask/000109_000000.png
#   inflating: test/000015/mask_visib/000109_000000.png
#   inflating: test/000015/rgb/000110.png
#   inflating: test/000015/depth/000110.png
#   inflating: test/000015/mask/000110_000000.png
#   inflating: test/000015/mask_visib/000110_000000.png
#   inflating: test/000015/rgb/000111.png
#   inflating: test/000015/depth/000111.png
#   inflating: test/000015/mask/000111_000000.png
#   inflating: test/000015/mask_visib/000111_000000.png
#   inflating: test/000015/rgb/000112.png
#   inflating: test/000015/depth/000112.png
#   inflating: test/000015/mask/000112_000000.png
#   inflating: test/000015/mask_visib/000112_000000.png
#   inflating: test/000015/rgb/000113.png
#   inflating: test/000015/depth/000113.png
#   inflating: test/000015/mask/000113_000000.png
#   inflating: test/000015/mask_visib/000113_000000.png
#   inflating: test/000015/rgb/000114.png
#   inflating: test/000015/depth/000114.png
#   inflating: test/000015/mask/000114_000000.png
#   inflating: test/000015/mask_visib/000114_000000.png
#   inflating: test/000015/rgb/000115.png
#   inflating: test/000015/depth/000115.png
#   inflating: test/000015/mask/000115_000000.png
#   inflating: test/000015/mask_visib/000115_000000.png
#   inflating: test/000015/rgb/000116.png
#   inflating: test/000015/depth/000116.png
#   inflating: test/000015/mask/000116_000000.png
#   inflating: test/000015/mask_visib/000116_000000.png
#   inflating: test/000015/rgb/000117.png
#   inflating: test/000015/depth/000117.png
#   inflating: test/000015/mask/000117_000000.png
#   inflating: test/000015/mask_visib/000117_000000.png
#   inflating: test/000015/rgb/000118.png
#   inflating: test/000015/depth/000118.png
#   inflating: test/000015/mask/000118_000000.png
#   inflating: test/000015/mask_visib/000118_000000.png
#   inflating: test/000015/rgb/000119.png
#   inflating: test/000015/depth/000119.png
#   inflating: test/000015/mask/000119_000000.png
#   inflating: test/000015/mask_visib/000119_000000.png
#   inflating: test/000015/rgb/000120.png
#   inflating: test/000015/depth/000120.png
#   inflating: test/000015/mask/000120_000000.png
#   inflating: test/000015/mask_visib/000120_000000.png
#   inflating: test/000015/rgb/000121.png
#   inflating: test/000015/depth/000121.png
#   inflating: test/000015/mask/000121_000000.png
#   inflating: test/000015/mask_visib/000121_000000.png
#   inflating: test/000015/rgb/000122.png
#   inflating: test/000015/depth/000122.png
#   inflating: test/000015/mask/000122_000000.png
#   inflating: test/000015/mask_visib/000122_000000.png
#   inflating: test/000015/rgb/000123.png
#   inflating: test/000015/depth/000123.png
#   inflating: test/000015/mask/000123_000000.png
#   inflating: test/000015/mask_visib/000123_000000.png
#   inflating: test/000015/rgb/000124.png
#   inflating: test/000015/depth/000124.png
#   inflating: test/000015/mask/000124_000000.png
#   inflating: test/000015/mask_visib/000124_000000.png
#   inflating: test/000015/rgb/000125.png
#   inflating: test/000015/depth/000125.png
#   inflating: test/000015/mask/000125_000000.png
#   inflating: test/000015/mask_visib/000125_000000.png
#   inflating: test/000015/rgb/000126.png
#   inflating: test/000015/depth/000126.png
#   inflating: test/000015/mask/000126_000000.png
#   inflating: test/000015/mask_visib/000126_000000.png
#   inflating: test/000015/rgb/000127.png
#   inflating: test/000015/depth/000127.png
#   inflating: test/000015/mask/000127_000000.png
#   inflating: test/000015/mask_visib/000127_000000.png
#   inflating: test/000015/rgb/000128.png
#   inflating: test/000015/depth/000128.png
#   inflating: test/000015/mask/000128_000000.png
#   inflating: test/000015/mask_visib/000128_000000.png
#   inflating: test/000015/rgb/000129.png
#   inflating: test/000015/depth/000129.png
#   inflating: test/000015/mask/000129_000000.png
#   inflating: test/000015/mask_visib/000129_000000.png
#   inflating: test/000015/rgb/000130.png
#   inflating: test/000015/depth/000130.png
#   inflating: test/000015/mask/000130_000000.png
#   inflating: test/000015/mask_visib/000130_000000.png
#   inflating: test/000015/rgb/000131.png
#   inflating: test/000015/depth/000131.png
#   inflating: test/000015/mask/000131_000000.png
#   inflating: test/000015/mask_visib/000131_000000.png
#   inflating: test/000015/rgb/000132.png
#   inflating: test/000015/depth/000132.png
#   inflating: test/000015/mask/000132_000000.png
#   inflating: test/000015/mask_visib/000132_000000.png
#   inflating: test/000015/rgb/000133.png
#   inflating: test/000015/depth/000133.png
#   inflating: test/000015/mask/000133_000000.png
#   inflating: test/000015/mask_visib/000133_000000.png
#   inflating: test/000015/rgb/000134.png
#   inflating: test/000015/depth/000134.png
#   inflating: test/000015/mask/000134_000000.png
#   inflating: test/000015/mask_visib/000134_000000.png
#   inflating: test/000015/rgb/000135.png
#   inflating: test/000015/depth/000135.png
#   inflating: test/000015/mask/000135_000000.png
#   inflating: test/000015/mask_visib/000135_000000.png
#   inflating: test/000015/rgb/000136.png
#   inflating: test/000015/depth/000136.png
#   inflating: test/000015/mask/000136_000000.png
#   inflating: test/000015/mask_visib/000136_000000.png
#   inflating: test/000015/rgb/000137.png
#   inflating: test/000015/depth/000137.png
#   inflating: test/000015/mask/000137_000000.png
#   inflating: test/000015/mask_visib/000137_000000.png
#   inflating: test/000015/rgb/000138.png
#   inflating: test/000015/depth/000138.png
#   inflating: test/000015/mask/000138_000000.png
#   inflating: test/000015/mask_visib/000138_000000.png
#   inflating: test/000015/rgb/000139.png
#   inflating: test/000015/depth/000139.png
#   inflating: test/000015/mask/000139_000000.png
#   inflating: test/000015/mask_visib/000139_000000.png
#   inflating: test/000015/rgb/000140.png
#   inflating: test/000015/depth/000140.png
#   inflating: test/000015/mask/000140_000000.png
#   inflating: test/000015/mask_visib/000140_000000.png
#   inflating: test/000015/rgb/000141.png
#   inflating: test/000015/depth/000141.png
#   inflating: test/000015/mask/000141_000000.png
#   inflating: test/000015/mask_visib/000141_000000.png
#   inflating: test/000015/rgb/000142.png
#   inflating: test/000015/depth/000142.png
#   inflating: test/000015/mask/000142_000000.png
#   inflating: test/000015/mask_visib/000142_000000.png
#   inflating: test/000015/rgb/000143.png
#   inflating: test/000015/depth/000143.png
#   inflating: test/000015/mask/000143_000000.png
#   inflating: test/000015/mask_visib/000143_000000.png
#   inflating: test/000015/rgb/000144.png
#   inflating: test/000015/depth/000144.png
#   inflating: test/000015/mask/000144_000000.png
#   inflating: test/000015/mask_visib/000144_000000.png
#   inflating: test/000015/rgb/000145.png
#   inflating: test/000015/depth/000145.png
#   inflating: test/000015/mask/000145_000000.png
#   inflating: test/000015/mask_visib/000145_000000.png
#   inflating: test/000015/rgb/000146.png
#   inflating: test/000015/depth/000146.png
#   inflating: test/000015/mask/000146_000000.png
#   inflating: test/000015/mask_visib/000146_000000.png
#   inflating: test/000015/rgb/000147.png
#   inflating: test/000015/depth/000147.png
#   inflating: test/000015/mask/000147_000000.png
#   inflating: test/000015/mask_visib/000147_000000.png
#   inflating: test/000015/rgb/000148.png
#   inflating: test/000015/depth/000148.png
#   inflating: test/000015/mask/000148_000000.png
#   inflating: test/000015/mask_visib/000148_000000.png
#   inflating: test/000015/rgb/000149.png
#   inflating: test/000015/depth/000149.png
#   inflating: test/000015/mask/000149_000000.png
#   inflating: test/000015/mask_visib/000149_000000.png
#   inflating: test/000015/rgb/000150.png
#   inflating: test/000015/depth/000150.png
#   inflating: test/000015/mask/000150_000000.png
#   inflating: test/000015/mask_visib/000150_000000.png
#   inflating: test/000015/rgb/000151.png
#   inflating: test/000015/depth/000151.png
#   inflating: test/000015/mask/000151_000000.png
#   inflating: test/000015/mask_visib/000151_000000.png
#   inflating: test/000015/rgb/000152.png
#   inflating: test/000015/depth/000152.png
#   inflating: test/000015/mask/000152_000000.png
#   inflating: test/000015/mask_visib/000152_000000.png
#   inflating: test/000015/rgb/000153.png
#   inflating: test/000015/depth/000153.png
#   inflating: test/000015/mask/000153_000000.png
#   inflating: test/000015/mask_visib/000153_000000.png
#   inflating: test/000015/rgb/000154.png
#   inflating: test/000015/depth/000154.png
#   inflating: test/000015/mask/000154_000000.png
#   inflating: test/000015/mask_visib/000154_000000.png
#   inflating: test/000015/rgb/000155.png
#   inflating: test/000015/depth/000155.png
#   inflating: test/000015/mask/000155_000000.png
#   inflating: test/000015/mask_visib/000155_000000.png
#   inflating: test/000015/rgb/000156.png
#   inflating: test/000015/depth/000156.png
#   inflating: test/000015/mask/000156_000000.png
#   inflating: test/000015/mask_visib/000156_000000.png
#   inflating: test/000015/rgb/000157.png
#   inflating: test/000015/depth/000157.png
#   inflating: test/000015/mask/000157_000000.png
#   inflating: test/000015/mask_visib/000157_000000.png
#   inflating: test/000015/rgb/000158.png
#   inflating: test/000015/depth/000158.png
#   inflating: test/000015/mask/000158_000000.png
#   inflating: test/000015/mask_visib/000158_000000.png
#   inflating: test/000015/rgb/000159.png
#   inflating: test/000015/depth/000159.png
#   inflating: test/000015/mask/000159_000000.png
#   inflating: test/000015/mask_visib/000159_000000.png
#   inflating: test/000015/rgb/000160.png
#   inflating: test/000015/depth/000160.png
#   inflating: test/000015/mask/000160_000000.png
#   inflating: test/000015/mask_visib/000160_000000.png
#   inflating: test/000015/rgb/000161.png
#   inflating: test/000015/depth/000161.png
#   inflating: test/000015/mask/000161_000000.png
#   inflating: test/000015/mask_visib/000161_000000.png
#   inflating: test/000015/rgb/000162.png
#   inflating: test/000015/depth/000162.png
#   inflating: test/000015/mask/000162_000000.png
#   inflating: test/000015/mask_visib/000162_000000.png
#   inflating: test/000015/rgb/000163.png
#   inflating: test/000015/depth/000163.png
#   inflating: test/000015/mask/000163_000000.png
#   inflating: test/000015/mask_visib/000163_000000.png
#   inflating: test/000015/rgb/000164.png
#   inflating: test/000015/depth/000164.png
#   inflating: test/000015/mask/000164_000000.png
#   inflating: test/000015/mask_visib/000164_000000.png
#   inflating: test/000015/rgb/000165.png
#   inflating: test/000015/depth/000165.png
#   inflating: test/000015/mask/000165_000000.png
#   inflating: test/000015/mask_visib/000165_000000.png
#   inflating: test/000015/rgb/000166.png
#   inflating: test/000015/depth/000166.png
#   inflating: test/000015/mask/000166_000000.png
#   inflating: test/000015/mask_visib/000166_000000.png
#   inflating: test/000015/rgb/000167.png
#   inflating: test/000015/depth/000167.png
#   inflating: test/000015/mask/000167_000000.png
#   inflating: test/000015/mask_visib/000167_000000.png
#   inflating: test/000015/rgb/000168.png
#   inflating: test/000015/depth/000168.png
#   inflating: test/000015/mask/000168_000000.png
#   inflating: test/000015/mask_visib/000168_000000.png
#   inflating: test/000015/rgb/000169.png
#   inflating: test/000015/depth/000169.png
#   inflating: test/000015/mask/000169_000000.png
#   inflating: test/000015/mask_visib/000169_000000.png
#   inflating: test/000015/rgb/000170.png
#   inflating: test/000015/depth/000170.png
#   inflating: test/000015/mask/000170_000000.png
#   inflating: test/000015/mask_visib/000170_000000.png
#   inflating: test/000015/rgb/000171.png
#   inflating: test/000015/depth/000171.png
#   inflating: test/000015/mask/000171_000000.png
#   inflating: test/000015/mask_visib/000171_000000.png
#   inflating: test/000015/rgb/000172.png
#   inflating: test/000015/depth/000172.png
#   inflating: test/000015/mask/000172_000000.png
#   inflating: test/000015/mask_visib/000172_000000.png
#   inflating: test/000015/rgb/000173.png
#   inflating: test/000015/depth/000173.png
#   inflating: test/000015/mask/000173_000000.png
#   inflating: test/000015/mask_visib/000173_000000.png
#   inflating: test/000015/rgb/000174.png
#   inflating: test/000015/depth/000174.png
#   inflating: test/000015/mask/000174_000000.png
#   inflating: test/000015/mask_visib/000174_000000.png
#   inflating: test/000015/rgb/000175.png
#   inflating: test/000015/depth/000175.png
#   inflating: test/000015/mask/000175_000000.png
#   inflating: test/000015/mask_visib/000175_000000.png
#   inflating: test/000015/rgb/000176.png
#   inflating: test/000015/depth/000176.png
#   inflating: test/000015/mask/000176_000000.png
#   inflating: test/000015/mask_visib/000176_000000.png
#   inflating: test/000015/rgb/000177.png
#   inflating: test/000015/depth/000177.png
#   inflating: test/000015/mask/000177_000000.png
#   inflating: test/000015/mask_visib/000177_000000.png
#   inflating: test/000015/rgb/000178.png
#   inflating: test/000015/depth/000178.png
#   inflating: test/000015/mask/000178_000000.png
#   inflating: test/000015/mask_visib/000178_000000.png
#   inflating: test/000015/rgb/000179.png
#   inflating: test/000015/depth/000179.png
#   inflating: test/000015/mask/000179_000000.png
#   inflating: test/000015/mask_visib/000179_000000.png
#   inflating: test/000015/rgb/000180.png
#   inflating: test/000015/depth/000180.png
#   inflating: test/000015/mask/000180_000000.png
#   inflating: test/000015/mask_visib/000180_000000.png
#   inflating: test/000015/rgb/000181.png
#   inflating: test/000015/depth/000181.png
#   inflating: test/000015/mask/000181_000000.png
#   inflating: test/000015/mask_visib/000181_000000.png
#   inflating: test/000015/rgb/000182.png
#   inflating: test/000015/depth/000182.png
#   inflating: test/000015/mask/000182_000000.png
#   inflating: test/000015/mask_visib/000182_000000.png
#   inflating: test/000015/rgb/000183.png
#   inflating: test/000015/depth/000183.png
#   inflating: test/000015/mask/000183_000000.png
#   inflating: test/000015/mask_visib/000183_000000.png
#   inflating: test/000015/rgb/000184.png
#   inflating: test/000015/depth/000184.png
#   inflating: test/000015/mask/000184_000000.png
#   inflating: test/000015/mask_visib/000184_000000.png
#   inflating: test/000015/rgb/000185.png
#   inflating: test/000015/depth/000185.png
#   inflating: test/000015/mask/000185_000000.png
#   inflating: test/000015/mask_visib/000185_000000.png
#   inflating: test/000015/rgb/000186.png
#   inflating: test/000015/depth/000186.png
#   inflating: test/000015/mask/000186_000000.png
#   inflating: test/000015/mask_visib/000186_000000.png
#   inflating: test/000015/rgb/000187.png
#   inflating: test/000015/depth/000187.png
#   inflating: test/000015/mask/000187_000000.png
#   inflating: test/000015/mask_visib/000187_000000.png
#   inflating: test/000015/rgb/000188.png
#   inflating: test/000015/depth/000188.png
#   inflating: test/000015/mask/000188_000000.png
#   inflating: test/000015/mask_visib/000188_000000.png
#   inflating: test/000015/rgb/000189.png
#   inflating: test/000015/depth/000189.png
#   inflating: test/000015/mask/000189_000000.png
#   inflating: test/000015/mask_visib/000189_000000.png
#   inflating: test/000015/rgb/000190.png
#   inflating: test/000015/depth/000190.png
#   inflating: test/000015/mask/000190_000000.png
#   inflating: test/000015/mask_visib/000190_000000.png
#   inflating: test/000015/rgb/000191.png
#   inflating: test/000015/depth/000191.png
#   inflating: test/000015/mask/000191_000000.png
#   inflating: test/000015/mask_visib/000191_000000.png
#   inflating: test/000015/rgb/000192.png
#   inflating: test/000015/depth/000192.png
#   inflating: test/000015/mask/000192_000000.png
#   inflating: test/000015/mask_visib/000192_000000.png
#   inflating: test/000015/rgb/000193.png
#   inflating: test/000015/depth/000193.png
#   inflating: test/000015/mask/000193_000000.png
#   inflating: test/000015/mask_visib/000193_000000.png
#   inflating: test/000015/rgb/000194.png
#   inflating: test/000015/depth/000194.png
#   inflating: test/000015/mask/000194_000000.png
#   inflating: test/000015/mask_visib/000194_000000.png
#   inflating: test/000015/rgb/000195.png
#   inflating: test/000015/depth/000195.png
#   inflating: test/000015/mask/000195_000000.png
#   inflating: test/000015/mask_visib/000195_000000.png
#   inflating: test/000015/rgb/000196.png
#   inflating: test/000015/depth/000196.png
#   inflating: test/000015/mask/000196_000000.png
#   inflating: test/000015/mask_visib/000196_000000.png
#   inflating: test/000015/rgb/000197.png
#   inflating: test/000015/depth/000197.png
#   inflating: test/000015/mask/000197_000000.png
#   inflating: test/000015/mask_visib/000197_000000.png
#   inflating: test/000015/rgb/000198.png
#   inflating: test/000015/depth/000198.png
#   inflating: test/000015/mask/000198_000000.png
#   inflating: test/000015/mask_visib/000198_000000.png
#   inflating: test/000015/rgb/000199.png
#   inflating: test/000015/depth/000199.png
#   inflating: test/000015/mask/000199_000000.png
#   inflating: test/000015/mask_visib/000199_000000.png
#   inflating: test/000015/rgb/000200.png
#   inflating: test/000015/depth/000200.png
#   inflating: test/000015/mask/000200_000000.png
#   inflating: test/000015/mask_visib/000200_000000.png
#   inflating: test/000015/rgb/000201.png
#   inflating: test/000015/depth/000201.png
#   inflating: test/000015/mask/000201_000000.png
#   inflating: test/000015/mask_visib/000201_000000.png
#   inflating: test/000015/rgb/000202.png
#   inflating: test/000015/depth/000202.png
#   inflating: test/000015/mask/000202_000000.png
#   inflating: test/000015/mask_visib/000202_000000.png
#   inflating: test/000015/rgb/000203.png
#   inflating: test/000015/depth/000203.png
#   inflating: test/000015/mask/000203_000000.png
#   inflating: test/000015/mask_visib/000203_000000.png
#   inflating: test/000015/rgb/000204.png
#   inflating: test/000015/depth/000204.png
#   inflating: test/000015/mask/000204_000000.png
#   inflating: test/000015/mask_visib/000204_000000.png
#   inflating: test/000015/rgb/000205.png
#   inflating: test/000015/depth/000205.png
#   inflating: test/000015/mask/000205_000000.png
#   inflating: test/000015/mask_visib/000205_000000.png
#   inflating: test/000015/rgb/000206.png
#   inflating: test/000015/depth/000206.png
#   inflating: test/000015/mask/000206_000000.png
#   inflating: test/000015/mask_visib/000206_000000.png
#   inflating: test/000015/rgb/000207.png
#   inflating: test/000015/depth/000207.png
#   inflating: test/000015/mask/000207_000000.png
#   inflating: test/000015/mask_visib/000207_000000.png
#   inflating: test/000015/rgb/000208.png
#   inflating: test/000015/depth/000208.png
#   inflating: test/000015/mask/000208_000000.png
#   inflating: test/000015/mask_visib/000208_000000.png
#   inflating: test/000015/rgb/000209.png
#   inflating: test/000015/depth/000209.png
#   inflating: test/000015/mask/000209_000000.png
#   inflating: test/000015/mask_visib/000209_000000.png
#   inflating: test/000015/rgb/000210.png
#   inflating: test/000015/depth/000210.png
#   inflating: test/000015/mask/000210_000000.png
#   inflating: test/000015/mask_visib/000210_000000.png
#   inflating: test/000015/rgb/000211.png
#   inflating: test/000015/depth/000211.png
#   inflating: test/000015/mask/000211_000000.png
#   inflating: test/000015/mask_visib/000211_000000.png
#   inflating: test/000015/rgb/000212.png
#   inflating: test/000015/depth/000212.png
#   inflating: test/000015/mask/000212_000000.png
#   inflating: test/000015/mask_visib/000212_000000.png
#   inflating: test/000015/rgb/000213.png
#   inflating: test/000015/depth/000213.png
#   inflating: test/000015/mask/000213_000000.png
#   inflating: test/000015/mask_visib/000213_000000.png
#   inflating: test/000015/rgb/000214.png
#   inflating: test/000015/depth/000214.png
#   inflating: test/000015/mask/000214_000000.png
#   inflating: test/000015/mask_visib/000214_000000.png
#   inflating: test/000015/rgb/000215.png
#   inflating: test/000015/depth/000215.png
#   inflating: test/000015/mask/000215_000000.png
#   inflating: test/000015/mask_visib/000215_000000.png
#   inflating: test/000015/rgb/000216.png
#   inflating: test/000015/depth/000216.png
#   inflating: test/000015/mask/000216_000000.png
#   inflating: test/000015/mask_visib/000216_000000.png
#   inflating: test/000015/rgb/000217.png
#   inflating: test/000015/depth/000217.png
#   inflating: test/000015/mask/000217_000000.png
#   inflating: test/000015/mask_visib/000217_000000.png
#   inflating: test/000015/rgb/000218.png
#   inflating: test/000015/depth/000218.png
#   inflating: test/000015/mask/000218_000000.png
#   inflating: test/000015/mask_visib/000218_000000.png
#   inflating: test/000015/rgb/000219.png
#   inflating: test/000015/depth/000219.png
#   inflating: test/000015/mask/000219_000000.png
#   inflating: test/000015/mask_visib/000219_000000.png
#   inflating: test/000015/rgb/000220.png
#   inflating: test/000015/depth/000220.png
#   inflating: test/000015/mask/000220_000000.png
#   inflating: test/000015/mask_visib/000220_000000.png
#   inflating: test/000015/rgb/000221.png
#   inflating: test/000015/depth/000221.png
#   inflating: test/000015/mask/000221_000000.png
#   inflating: test/000015/mask_visib/000221_000000.png
#   inflating: test/000015/rgb/000222.png
#   inflating: test/000015/depth/000222.png
#   inflating: test/000015/mask/000222_000000.png
#   inflating: test/000015/mask_visib/000222_000000.png
#   inflating: test/000015/rgb/000223.png
#   inflating: test/000015/depth/000223.png
#   inflating: test/000015/mask/000223_000000.png
#   inflating: test/000015/mask_visib/000223_000000.png
#   inflating: test/000015/rgb/000224.png
#   inflating: test/000015/depth/000224.png
#   inflating: test/000015/mask/000224_000000.png
#   inflating: test/000015/mask_visib/000224_000000.png
#   inflating: test/000015/rgb/000225.png
#   inflating: test/000015/depth/000225.png
#   inflating: test/000015/mask/000225_000000.png
#   inflating: test/000015/mask_visib/000225_000000.png
#   inflating: test/000015/rgb/000226.png
#   inflating: test/000015/depth/000226.png
#   inflating: test/000015/mask/000226_000000.png
#   inflating: test/000015/mask_visib/000226_000000.png
#   inflating: test/000015/rgb/000227.png
#   inflating: test/000015/depth/000227.png
#   inflating: test/000015/mask/000227_000000.png
#   inflating: test/000015/mask_visib/000227_000000.png
#   inflating: test/000015/rgb/000228.png
#   inflating: test/000015/depth/000228.png
#   inflating: test/000015/mask/000228_000000.png
#   inflating: test/000015/mask_visib/000228_000000.png
#   inflating: test/000015/rgb/000229.png
#   inflating: test/000015/depth/000229.png
#   inflating: test/000015/mask/000229_000000.png
#   inflating: test/000015/mask_visib/000229_000000.png
#   inflating: test/000015/rgb/000230.png
#   inflating: test/000015/depth/000230.png
#   inflating: test/000015/mask/000230_000000.png
#   inflating: test/000015/mask_visib/000230_000000.png
#   inflating: test/000015/rgb/000231.png
#   inflating: test/000015/depth/000231.png
#   inflating: test/000015/mask/000231_000000.png
#   inflating: test/000015/mask_visib/000231_000000.png
#   inflating: test/000015/rgb/000232.png
#   inflating: test/000015/depth/000232.png
#   inflating: test/000015/mask/000232_000000.png
#   inflating: test/000015/mask_visib/000232_000000.png
#   inflating: test/000015/rgb/000233.png
#   inflating: test/000015/depth/000233.png
#   inflating: test/000015/mask/000233_000000.png
#   inflating: test/000015/mask_visib/000233_000000.png
#   inflating: test/000015/rgb/000234.png
#   inflating: test/000015/depth/000234.png
#   inflating: test/000015/mask/000234_000000.png
#   inflating: test/000015/mask_visib/000234_000000.png
#   inflating: test/000015/rgb/000235.png
#   inflating: test/000015/depth/000235.png
#   inflating: test/000015/mask/000235_000000.png
#   inflating: test/000015/mask_visib/000235_000000.png
#   inflating: test/000015/rgb/000236.png
#   inflating: test/000015/depth/000236.png
#   inflating: test/000015/mask/000236_000000.png
#   inflating: test/000015/mask_visib/000236_000000.png
#   inflating: test/000015/rgb/000237.png
#   inflating: test/000015/depth/000237.png
#   inflating: test/000015/mask/000237_000000.png
#   inflating: test/000015/mask_visib/000237_000000.png
#   inflating: test/000015/rgb/000238.png
#   inflating: test/000015/depth/000238.png
#   inflating: test/000015/mask/000238_000000.png
#   inflating: test/000015/mask_visib/000238_000000.png
#   inflating: test/000015/rgb/000239.png
#   inflating: test/000015/depth/000239.png
#   inflating: test/000015/mask/000239_000000.png
#   inflating: test/000015/mask_visib/000239_000000.png
#   inflating: test/000015/rgb/000240.png
#   inflating: test/000015/depth/000240.png
#   inflating: test/000015/mask/000240_000000.png
#   inflating: test/000015/mask_visib/000240_000000.png
#   inflating: test/000015/rgb/000241.png
#   inflating: test/000015/depth/000241.png
#   inflating: test/000015/mask/000241_000000.png
#   inflating: test/000015/mask_visib/000241_000000.png
#   inflating: test/000015/rgb/000242.png
#   inflating: test/000015/depth/000242.png
#   inflating: test/000015/mask/000242_000000.png
# ...
#   inflating: test/000015/mask_visib/001159_000000.png
#   inflating: test/000015/rgb/001160.png
#   inflating: test/000015/depth/001160.png
#   inflating: test/000015/mask/001160_000000.png
#   inflating: test/000015/mask_visib/001160_000000.png
#   inflating: test/000015/rgb/001161.png
#   inflating: test/000015/depth/001161.png
#   inflating: test/000015/mask/001161_000000.png
#   inflating: test/000015/mask_visib/001161_000000.png
#   inflating: test/000015/rgb/001162.png
#   inflating: test/000015/depth/001162.png
#   inflating: test/000015/mask/001162_000000.png
#   inflating: test/000015/mask_visib/001162_000000.png
#   inflating: test/000015/rgb/001163.png
#   inflating: test/000015/depth/001163.png
#   inflating: test/000015/mask/001163_000000.png
#   inflating: test/000015/mask_visib/001163_000000.png
#   inflating: test/000015/rgb/001164.png
#   inflating: test/000015/depth/001164.png
#   inflating: test/000015/mask/001164_000000.png
#   inflating: test/000015/mask_visib/001164_000000.png
#   inflating: test/000015/rgb/001165.png
#   inflating: test/000015/depth/001165.png
#   inflating: test/000015/mask/001165_000000.png
#   inflating: test/000015/mask_visib/001165_000000.png
#   inflating: test/000015/rgb/001166.png
#   inflating: test/000015/depth/001166.png
#   inflating: test/000015/mask/001166_000000.png
#   inflating: test/000015/mask_visib/001166_000000.png
#   inflating: test/000015/rgb/001167.png
#   inflating: test/000015/depth/001167.png
#   inflating: test/000015/mask/001167_000000.png
#   inflating: test/000015/mask_visib/001167_000000.png
#   inflating: test/000015/rgb/001168.png
#   inflating: test/000015/depth/001168.png
#   inflating: test/000015/mask/001168_000000.png
#   inflating: test/000015/mask_visib/001168_000000.png
#   inflating: test/000015/rgb/001169.png
#   inflating: test/000015/depth/001169.png
#   inflating: test/000015/mask/001169_000000.png
#   inflating: test/000015/mask_visib/001169_000000.png
#   inflating: test/000015/rgb/001170.png
#   inflating: test/000015/depth/001170.png
#   inflating: test/000015/mask/001170_000000.png
#   inflating: test/000015/mask_visib/001170_000000.png
#   inflating: test/000015/rgb/001171.png
#   inflating: test/000015/depth/001171.png
#   inflating: test/000015/mask/001171_000000.png
#   inflating: test/000015/mask_visib/001171_000000.png
#   inflating: test/000015/rgb/001172.png
#   inflating: test/000015/depth/001172.png
#   inflating: test/000015/mask/001172_000000.png
#   inflating: test/000015/mask_visib/001172_000000.png
#   inflating: test/000015/rgb/001173.png
#   inflating: test/000015/depth/001173.png
#   inflating: test/000015/mask/001173_000000.png
#   inflating: test/000015/mask_visib/001173_000000.png
#   inflating: test/000015/rgb/001174.png
#   inflating: test/000015/depth/001174.png
#   inflating: test/000015/mask/001174_000000.png
#   inflating: test/000015/mask_visib/001174_000000.png
#   inflating: test/000015/rgb/001175.png
#   inflating: test/000015/depth/001175.png
#   inflating: test/000015/mask/001175_000000.png
#   inflating: test/000015/mask_visib/001175_000000.png
#   inflating: test/000015/rgb/001176.png
#   inflating: test/000015/depth/001176.png
#   inflating: test/000015/mask/001176_000000.png
#   inflating: test/000015/mask_visib/001176_000000.png
#   inflating: test/000015/rgb/001177.png
#   inflating: test/000015/depth/001177.png
#   inflating: test/000015/mask/001177_000000.png
#   inflating: test/000015/mask_visib/001177_000000.png
#   inflating: test/000015/rgb/001178.png
#   inflating: test/000015/depth/001178.png
#   inflating: test/000015/mask/001178_000000.png
#   inflating: test/000015/mask_visib/001178_000000.png
#   inflating: test/000015/rgb/001179.png
#   inflating: test/000015/depth/001179.png
#   inflating: test/000015/mask/001179_000000.png
#   inflating: test/000015/mask_visib/001179_000000.png
#   inflating: test/000015/rgb/001180.png
#   inflating: test/000015/depth/001180.png
#   inflating: test/000015/mask/001180_000000.png
#   inflating: test/000015/mask_visib/001180_000000.png
#   inflating: test/000015/rgb/001181.png
#   inflating: test/000015/depth/001181.png
#   inflating: test/000015/mask/001181_000000.png
#   inflating: test/000015/mask_visib/001181_000000.png
#   inflating: test/000015/rgb/001182.png
#   inflating: test/000015/depth/001182.png
#   inflating: test/000015/mask/001182_000000.png
#   inflating: test/000015/mask_visib/001182_000000.png
#   inflating: test/000015/rgb/001183.png
#   inflating: test/000015/depth/001183.png
#   inflating: test/000015/mask/001183_000000.png
#   inflating: test/000015/mask_visib/001183_000000.png
#   inflating: test/000015/rgb/001184.png
#   inflating: test/000015/depth/001184.png
#   inflating: test/000015/mask/001184_000000.png
#   inflating: test/000015/mask_visib/001184_000000.png
#   inflating: test/000015/rgb/001185.png
#   inflating: test/000015/depth/001185.png
#   inflating: test/000015/mask/001185_000000.png
#   inflating: test/000015/mask_visib/001185_000000.png
#   inflating: test/000015/rgb/001186.png
#   inflating: test/000015/depth/001186.png
#   inflating: test/000015/mask/001186_000000.png
#   inflating: test/000015/mask_visib/001186_000000.png
#   inflating: test/000015/rgb/001187.png
#   inflating: test/000015/depth/001187.png
#   inflating: test/000015/mask/001187_000000.png
#   inflating: test/000015/mask_visib/001187_000000.png
#   inflating: test/000015/rgb/001188.png
#   inflating: test/000015/depth/001188.png
#   inflating: test/000015/mask/001188_000000.png
#   inflating: test/000015/mask_visib/001188_000000.png
#   inflating: test/000015/rgb/001189.png
#   inflating: test/000015/depth/001189.png
#   inflating: test/000015/mask/001189_000000.png
#   inflating: test/000015/mask_visib/001189_000000.png
#   inflating: test/000015/rgb/001190.png
#   inflating: test/000015/depth/001190.png
#   inflating: test/000015/mask/001190_000000.png
#   inflating: test/000015/mask_visib/001190_000000.png
#   inflating: test/000015/rgb/001191.png
#   inflating: test/000015/depth/001191.png
#   inflating: test/000015/mask/001191_000000.png
#   inflating: test/000015/mask_visib/001191_000000.png
#   inflating: test/000015/rgb/001192.png
#   inflating: test/000015/depth/001192.png
#   inflating: test/000015/mask/001192_000000.png
#   inflating: test/000015/mask_visib/001192_000000.png
#   inflating: test/000015/rgb/001193.png
#   inflating: test/000015/depth/001193.png
#   inflating: test/000015/mask/001193_000000.png
#   inflating: test/000015/mask_visib/001193_000000.png
#   inflating: test/000015/rgb/001194.png
#   inflating: test/000015/depth/001194.png
#   inflating: test/000015/mask/001194_000000.png
#   inflating: test/000015/mask_visib/001194_000000.png
#   inflating: test/000015/rgb/001195.png
#   inflating: test/000015/depth/001195.png
#   inflating: test/000015/mask/001195_000000.png
#   inflating: test/000015/mask_visib/001195_000000.png
#   inflating: test/000015/rgb/001196.png
#   inflating: test/000015/depth/001196.png
#   inflating: test/000015/mask/001196_000000.png
#   inflating: test/000015/mask_visib/001196_000000.png
#   inflating: test/000015/rgb/001197.png
#   inflating: test/000015/depth/001197.png
#   inflating: test/000015/mask/001197_000000.png
#   inflating: test/000015/mask_visib/001197_000000.png
#   inflating: test/000015/rgb/001198.png
#   inflating: test/000015/depth/001198.png
#   inflating: test/000015/mask/001198_000000.png
#   inflating: test/000015/mask_visib/001198_000000.png
#   inflating: test/000015/rgb/001199.png
#   inflating: test/000015/depth/001199.png
#   inflating: test/000015/mask/001199_000000.png
#   inflating: test/000015/mask_visib/001199_000000.png
#   inflating: test/000015/rgb/001200.png
#   inflating: test/000015/depth/001200.png
#   inflating: test/000015/mask/001200_000000.png
#   inflating: test/000015/mask_visib/001200_000000.png
#   inflating: test/000015/rgb/001201.png
#   inflating: test/000015/depth/001201.png
#   inflating: test/000015/mask/001201_000000.png
#   inflating: test/000015/mask_visib/001201_000000.png
#   inflating: test/000015/rgb/001202.png
#   inflating: test/000015/depth/001202.png
#   inflating: test/000015/mask/001202_000000.png
#   inflating: test/000015/mask_visib/001202_000000.png
#   inflating: test/000015/rgb/001203.png
#   inflating: test/000015/depth/001203.png
#   inflating: test/000015/mask/001203_000000.png
#   inflating: test/000015/mask_visib/001203_000000.png
#   inflating: test/000015/rgb/001204.png
#   inflating: test/000015/depth/001204.png
#   inflating: test/000015/mask/001204_000000.png
#   inflating: test/000015/mask_visib/001204_000000.png
#   inflating: test/000015/rgb/001205.png
#   inflating: test/000015/depth/001205.png
#   inflating: test/000015/mask/001205_000000.png
#   inflating: test/000015/mask_visib/001205_000000.png
#   inflating: test/000015/rgb/001206.png
#   inflating: test/000015/depth/001206.png
#   inflating: test/000015/mask/001206_000000.png
#   inflating: test/000015/mask_visib/001206_000000.png
#   inflating: test/000015/rgb/001207.png
#   inflating: test/000015/depth/001207.png
#   inflating: test/000015/mask/001207_000000.png
#   inflating: test/000015/mask_visib/001207_000000.png
#   inflating: test/000015/rgb/001208.png
#   inflating: test/000015/depth/001208.png
#   inflating: test/000015/mask/001208_000000.png
#   inflating: test/000015/mask_visib/001208_000000.png
#   inflating: test/000015/rgb/001209.png
#   inflating: test/000015/depth/001209.png
#   inflating: test/000015/mask/001209_000000.png
#   inflating: test/000015/mask_visib/001209_000000.png
#   inflating: test/000015/rgb/001210.png
#   inflating: test/000015/depth/001210.png
#   inflating: test/000015/mask/001210_000000.png
#   inflating: test/000015/mask_visib/001210_000000.png
#   inflating: test/000015/rgb/001211.png
#   inflating: test/000015/depth/001211.png
#   inflating: test/000015/mask/001211_000000.png
#   inflating: test/000015/mask_visib/001211_000000.png
#   inflating: test/000015/rgb/001212.png
#   inflating: test/000015/depth/001212.png
#   inflating: test/000015/mask/001212_000000.png
#   inflating: test/000015/mask_visib/001212_000000.png
#   inflating: test/000015/rgb/001213.png
#   inflating: test/000015/depth/001213.png
#   inflating: test/000015/mask/001213_000000.png
#   inflating: test/000015/mask_visib/001213_000000.png
#   inflating: test/000015/rgb/001214.png
#   inflating: test/000015/depth/001214.png
#   inflating: test/000015/mask/001214_000000.png
#   inflating: test/000015/mask_visib/001214_000000.png
#   inflating: test/000015/rgb/001215.png
#   inflating: test/000015/depth/001215.png
#   inflating: test/000015/mask/001215_000000.png
#   inflating: test/000015/mask_visib/001215_000000.png
#   inflating: test/000015/rgb/001216.png
#   inflating: test/000015/depth/001216.png
#   inflating: test/000015/mask/001216_000000.png
#   inflating: test/000015/mask_visib/001216_000000.png
#   inflating: test/000015/rgb/001217.png
#   inflating: test/000015/depth/001217.png
#   inflating: test/000015/mask/001217_000000.png
#   inflating: test/000015/mask_visib/001217_000000.png
#   inflating: test/000015/rgb/001218.png
#   inflating: test/000015/depth/001218.png
#   inflating: test/000015/mask/001218_000000.png
#   inflating: test/000015/mask_visib/001218_000000.png
#   inflating: test/000015/rgb/001219.png
#   inflating: test/000015/depth/001219.png
#   inflating: test/000015/mask/001219_000000.png
#   inflating: test/000015/mask_visib/001219_000000.png
#   inflating: test/000015/rgb/001220.png
#   inflating: test/000015/depth/001220.png
#   inflating: test/000015/mask/001220_000000.png
#   inflating: test/000015/mask_visib/001220_000000.png
#   inflating: test/000015/rgb/001221.png
#   inflating: test/000015/depth/001221.png
#   inflating: test/000015/mask/001221_000000.png
#   inflating: test/000015/mask_visib/001221_000000.png
#   inflating: test/000015/rgb/001222.png
#   inflating: test/000015/depth/001222.png
#   inflating: test/000015/mask/001222_000000.png
#   inflating: test/000015/mask_visib/001222_000000.png
#   inflating: test/000015/rgb/001223.png
#   inflating: test/000015/depth/001223.png
#   inflating: test/000015/mask/001223_000000.png
#   inflating: test/000015/mask_visib/001223_000000.png
#   inflating: test/000015/rgb/001224.png
#   inflating: test/000015/depth/001224.png
#   inflating: test/000015/mask/001224_000000.png
#   inflating: test/000015/mask_visib/001224_000000.png
#   inflating: test/000015/rgb/001225.png
#   inflating: test/000015/depth/001225.png
#   inflating: test/000015/mask/001225_000000.png
#   inflating: test/000015/mask_visib/001225_000000.png
#   inflating: test/000015/rgb/001226.png
#   inflating: test/000015/depth/001226.png
#   inflating: test/000015/mask/001226_000000.png
#   inflating: test/000015/mask_visib/001226_000000.png
#   inflating: test/000015/rgb/001227.png
#   inflating: test/000015/depth/001227.png
#   inflating: test/000015/mask/001227_000000.png
#   inflating: test/000015/mask_visib/001227_000000.png
#   inflating: test/000015/rgb/001228.png
#   inflating: test/000015/depth/001228.png
#   inflating: test/000015/mask/001228_000000.png
#   inflating: test/000015/mask_visib/001228_000000.png
#   inflating: test/000015/rgb/001229.png
#   inflating: test/000015/depth/001229.png
#   inflating: test/000015/mask/001229_000000.png
#   inflating: test/000015/mask_visib/001229_000000.png
#   inflating: test/000015/rgb/001230.png
#   inflating: test/000015/depth/001230.png
#   inflating: test/000015/mask/001230_000000.png
#   inflating: test/000015/mask_visib/001230_000000.png
#   inflating: test/000015/rgb/001231.png
#   inflating: test/000015/depth/001231.png
#   inflating: test/000015/mask/001231_000000.png
#   inflating: test/000015/mask_visib/001231_000000.png
#   inflating: test/000015/rgb/001232.png
#   inflating: test/000015/depth/001232.png
#   inflating: test/000015/mask/001232_000000.png
#   inflating: test/000015/mask_visib/001232_000000.png
#   inflating: test/000015/rgb/001233.png
#   inflating: test/000015/depth/001233.png
#   inflating: test/000015/mask/001233_000000.png
#   inflating: test/000015/mask_visib/001233_000000.png
#   inflating: test/000015/rgb/001234.png
#   inflating: test/000015/depth/001234.png
#   inflating: test/000015/mask/001234_000000.png
#   inflating: test/000015/mask_visib/001234_000000.png
#   inflating: test/000015/rgb/001235.png
#   inflating: test/000015/depth/001235.png
#   inflating: test/000015/mask/001235_000000.png
#   inflating: test/000015/mask_visib/001235_000000.png
#   inflating: test/000015/rgb/001236.png
#   inflating: test/000015/depth/001236.png
#   inflating: test/000015/mask/001236_000000.png
#   inflating: test/000015/mask_visib/001236_000000.png
#   inflating: test/000015/rgb/001237.png
#   inflating: test/000015/depth/001237.png
#   inflating: test/000015/mask/001237_000000.png
#   inflating: test/000015/mask_visib/001237_000000.png
#   inflating: test/000015/rgb/001238.png
#   inflating: test/000015/depth/001238.png
#   inflating: test/000015/mask/001238_000000.png
#   inflating: test/000015/mask_visib/001238_000000.png
#   inflating: test/000015/rgb/001239.png
#   inflating: test/000015/depth/001239.png
#   inflating: test/000015/mask/001239_000000.png
#   inflating: test/000015/mask_visib/001239_000000.png
#   inflating: test/000015/rgb/001240.png
#   inflating: test/000015/depth/001240.png
#   inflating: test/000015/mask/001240_000000.png
#   inflating: test/000015/mask_visib/001240_000000.png
#   inflating: test/000015/rgb/001241.png
#   inflating: test/000015/depth/001241.png
#   inflating: test/000015/mask/001241_000000.png
#   inflating: test/000015/mask_visib/001241_000000.png
#   inflating: test/000015/rgb/001242.png
#   inflating: test/000015/depth/001242.png
#   inflating: test/000015/mask/001242_000000.png
#   inflating: test/000015/mask_visib/001242_000000.png

# %%
from scipy.spatial.transform import Rotation

def poses_to_quaternion_format(poses):
    """
    Convert a list of poses in the format:
    [[R11, R12, R13, tx],
     [R21, R22, R23, ty],
     [R31, R32, R33, tz]]
    into a list of poses in the format [tx, ty, tz, qx, qy, qz, qw].
    """
    quaternion_poses = []

    for pose in poses:
        pose_np = np.array(pose[0])  # Convert to numpy array.
        R = pose_np[:, :3]  # Extract the 3x3 rotation matrix.
        t = pose_np[:, 3]  # Extract the translation vector.

        # Convert rotation matrix to quaternion.
        rotation = Rotation.from_matrix(R)
        quaternion = rotation.as_quat()

        quaternion_pose = list(t) + list(quaternion)
        quaternion_poses.append(quaternion_pose)

    return quaternion_poses

# %%
# Paths
IMAGE_FOLDER = "test/000001/rgb"
SCENE_GT_PATH = "test/000001/scene_gt.json"
SCENE_CAMERA_PATH = "test/000001/scene_camera.json"

# Load images and JSON data
images = load_images_from_folder(IMAGE_FOLDER)
scene_gt = load_json(SCENE_GT_PATH)
scene_camera = load_json(SCENE_CAMERA_PATH)

# Process ground truth and camera parameters
poses, camera_params = process_gt_data(scene_gt, scene_camera)

# Preprocess images
images = preprocess_images(images)

# %%
quaternion_poses = poses_to_quaternion_format(poses)

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# Ensure TensorFlow is utilizing GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
else:
    print("No GPU found, model will be trained on CPU.")

# %%
# Create a MirroredStrategy.
strategy = tf.distribute.MirroredStrategy()

print('Number of devices: {}'.format(strategy.num_replicas_in_sync))

# Open a strategy scope.
with strategy.scope():
    # Define and compile the model.
    #model = create_6DoF_model_quaternion()
    model = create_resnet_6dof_model()
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse')
# Out:
# Number of devices: 1
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step

# %%
from sklearn.model_selection import train_test_split

# Split the data into 70% training data, 15% validation data, and 15% test data

# First, separate out the test set (15% of the total data)
X_temp, X_test, y_temp, y_test_quat = train_test_split(images, quaternion_poses, test_size=0.15, random_state=42)

# Now, split the remaining data (X_temp, y_temp) into training and validation sets
X_train, X_val, y_train_quat, y_val_quat = train_test_split(X_temp, y_temp, test_size=0.1765, random_state=42)  # 0.1765 of 85% is roughly 15%

# Convert lists to numpy arrays
y_train_quat = np.array(y_train_quat)
y_val_quat = np.array(y_val_quat)
y_test_quat = np.array(y_test_quat)

# %%
history = model.fit(X_train, y_train_quat,
                    validation_data=(X_val, y_val_quat),
                    epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 27/27 [==============================] - 15s 111ms/step - loss: 114194.0156 - val_loss: 106966.1328
# Epoch 2/150
# 27/27 [==============================] - 1s 41ms/step - loss: 112172.5547 - val_loss: 105096.4062
# Epoch 3/150
# 27/27 [==============================] - 1s 41ms/step - loss: 110258.8203 - val_loss: 103209.5234
# Epoch 4/150
# 27/27 [==============================] - 1s 42ms/step - loss: 108241.9453 - val_loss: 101162.3672
# Epoch 5/150
# 27/27 [==============================] - 1s 42ms/step - loss: 106010.3984 - val_loss: 98857.5078
# Epoch 6/150
# 27/27 [==============================] - 1s 42ms/step - loss: 103521.6484 - val_loss: 96313.8047
# Epoch 7/150
# 27/27 [==============================] - 1s 41ms/step - loss: 100790.9062 - val_loss: 93536.3906
# Epoch 8/150
# 27/27 [==============================] - 1s 41ms/step - loss: 97828.8125 - val_loss: 90549.2266
# Epoch 9/150
# 27/27 [==============================] - 1s 41ms/step - loss: 94658.8984 - val_loss: 87375.4062
# Epoch 10/150
# 27/27 [==============================] - 1s 41ms/step - loss: 91308.1094 - val_loss: 84022.0469
# Epoch 11/150
# 27/27 [==============================] - 1s 41ms/step - loss: 87779.7031 - val_loss: 80522.9531
# Epoch 12/150
# 27/27 [==============================] - 1s 41ms/step - loss: 84104.7031 - val_loss: 76896.7422
# Epoch 13/150
# 27/27 [==============================] - 1s 41ms/step - loss: 80307.5547 - val_loss: 73164.5234
# Epoch 14/150
# 27/27 [==============================] - 1s 41ms/step - loss: 76406.8906 - val_loss: 69356.2578
# Epoch 15/150
# 27/27 [==============================] - 1s 41ms/step - loss: 72440.2500 - val_loss: 65487.6016
# Epoch 16/150
# 27/27 [==============================] - 1s 41ms/step - loss: 68425.2578 - val_loss: 61598.1406
# Epoch 17/150
# 27/27 [==============================] - 1s 41ms/step - loss: 64397.6328 - val_loss: 57712.1289
# Epoch 18/150
# 27/27 [==============================] - 1s 41ms/step - loss: 60374.5938 - val_loss: 53861.1758
# Epoch 19/150
# 27/27 [==============================] - 1s 41ms/step - loss: 56393.0273 - val_loss: 50064.8594
# Epoch 20/150
# 27/27 [==============================] - 1s 41ms/step - loss: 52477.4844 - val_loss: 46348.8047
# Epoch 21/150
# 27/27 [==============================] - 1s 41ms/step - loss: 48643.1836 - val_loss: 42728.9258
# Epoch 22/150
# 27/27 [==============================] - 1s 41ms/step - loss: 44921.1445 - val_loss: 39239.0938
# Epoch 23/150
# 27/27 [==============================] - 1s 41ms/step - loss: 41325.2812 - val_loss: 35890.6758
# Epoch 24/150
# 27/27 [==============================] - 1s 41ms/step - loss: 37883.5977 - val_loss: 32693.9844
# Epoch 25/150
# 27/27 [==============================] - 1s 41ms/step - loss: 34602.5820 - val_loss: 29663.0156
# Epoch 26/150
# 27/27 [==============================] - 1s 41ms/step - loss: 31489.5918 - val_loss: 26829.5645
# Epoch 27/150
# 27/27 [==============================] - 1s 41ms/step - loss: 28583.0469 - val_loss: 24160.7480
# Epoch 28/150
# 27/27 [==============================] - 1s 41ms/step - loss: 25850.6719 - val_loss: 21707.5879
# Epoch 29/150
# 27/27 [==============================] - 1s 41ms/step - loss: 23324.8105 - val_loss: 19458.0938
# Epoch 30/150
# 27/27 [==============================] - 1s 41ms/step - loss: 21004.7227 - val_loss: 17398.3418
# Epoch 31/150
# 27/27 [==============================] - 1s 40ms/step - loss: 18879.8594 - val_loss: 15547.0059
# Epoch 32/150
# 27/27 [==============================] - 1s 41ms/step - loss: 16958.1191 - val_loss: 13878.7744
# Epoch 33/150
# 27/27 [==============================] - 1s 41ms/step - loss: 15224.9502 - val_loss: 12399.3818
# Epoch 34/150
# 27/27 [==============================] - 1s 41ms/step - loss: 13686.9170 - val_loss: 11092.7227
# Epoch 35/150
# 27/27 [==============================] - 1s 41ms/step - loss: 12320.1367 - val_loss: 9944.5830
# Epoch 36/150
# 27/27 [==============================] - 1s 41ms/step - loss: 11114.9453 - val_loss: 8967.9365
# Epoch 37/150
# 27/27 [==============================] - 1s 41ms/step - loss: 10078.2061 - val_loss: 8126.0342
# Epoch 38/150
# 27/27 [==============================] - 1s 41ms/step - loss: 9171.9863 - val_loss: 7420.5107
# Epoch 39/150
# 27/27 [==============================] - 1s 41ms/step - loss: 8404.6289 - val_loss: 6826.6875
# Epoch 40/150
# 27/27 [==============================] - 1s 41ms/step - loss: 7752.0474 - val_loss: 6327.5835
# Epoch 41/150
# 27/27 [==============================] - 1s 41ms/step - loss: 7200.5386 - val_loss: 5930.0952
# Epoch 42/150
# 27/27 [==============================] - 1s 41ms/step - loss: 6745.8320 - val_loss: 5608.8931
# Epoch 43/150
# 27/27 [==============================] - 1s 41ms/step - loss: 6366.3008 - val_loss: 5354.3594
# Epoch 44/150
# 27/27 [==============================] - 1s 41ms/step - loss: 6052.5747 - val_loss: 5156.5137
# Epoch 45/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5803.3887 - val_loss: 5002.1440
# Epoch 46/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5602.5020 - val_loss: 4883.9326
# Epoch 47/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5436.6709 - val_loss: 4802.9492
# Epoch 48/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5311.7207 - val_loss: 4737.6997
# Epoch 49/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5210.8975 - val_loss: 4697.4189
# Epoch 50/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5130.4956 - val_loss: 4672.1138
# Epoch 51/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5071.2378 - val_loss: 4655.6289
# Epoch 52/150
# 27/27 [==============================] - 1s 41ms/step - loss: 5020.8540 - val_loss: 4643.9038
# Epoch 53/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4988.5479 - val_loss: 4644.5884
# Epoch 54/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4957.5605 - val_loss: 4640.8291
# Epoch 55/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4935.7397 - val_loss: 4645.2065
# Epoch 56/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4918.9878 - val_loss: 4650.1060
# Epoch 57/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4907.0195 - val_loss: 4658.4058
# Epoch 58/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4894.7930 - val_loss: 4658.7310
# Epoch 59/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4886.7290 - val_loss: 4664.0176
# Epoch 60/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4879.8149 - val_loss: 4667.7876
# Epoch 61/150
# 27/27 [==============================] - 1s 42ms/step - loss: 4874.3687 - val_loss: 4671.1201
# Epoch 62/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4868.4800 - val_loss: 4669.2354
# Epoch 63/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4866.0044 - val_loss: 4671.0283
# Epoch 64/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4861.3228 - val_loss: 4673.0166
# Epoch 65/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4855.9351 - val_loss: 4676.1250
# Epoch 66/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4851.7173 - val_loss: 4674.6792
# Epoch 67/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4850.3169 - val_loss: 4681.1699
# Epoch 68/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4844.4927 - val_loss: 4668.6494
# Epoch 69/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4841.0903 - val_loss: 4670.1021
# Epoch 70/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4836.9043 - val_loss: 4667.9575
# Epoch 71/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4833.4771 - val_loss: 4661.8130
# Epoch 72/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4829.8105 - val_loss: 4657.3677
# Epoch 73/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4827.2505 - val_loss: 4657.6963
# Epoch 74/150
# 27/27 [==============================] - 1s 42ms/step - loss: 4822.3838 - val_loss: 4658.7227
# Epoch 75/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4819.0454 - val_loss: 4651.3369
# Epoch 76/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4815.2363 - val_loss: 4640.5264
# Epoch 77/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4811.2510 - val_loss: 4638.6426
# Epoch 78/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4807.2017 - val_loss: 4637.7246
# Epoch 79/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4803.0474 - val_loss: 4629.8281
# Epoch 80/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4798.8789 - val_loss: 4632.1401
# Epoch 81/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4794.1665 - val_loss: 4622.6670
# Epoch 82/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4790.7627 - val_loss: 4626.3354
# Epoch 83/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4786.0371 - val_loss: 4616.8306
# Epoch 84/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4781.7139 - val_loss: 4606.8389
# Epoch 85/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4777.7417 - val_loss: 4601.3926
# Epoch 86/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4773.4722 - val_loss: 4604.6001
# Epoch 87/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4768.9785 - val_loss: 4595.0161
# Epoch 88/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4765.8945 - val_loss: 4598.3667
# Epoch 89/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4760.8667 - val_loss: 4587.6035
# Epoch 90/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4754.9683 - val_loss: 4578.7998
# Epoch 91/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4751.6157 - val_loss: 4573.1733
# Epoch 92/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4747.1274 - val_loss: 4568.5791
# Epoch 93/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4744.7974 - val_loss: 4567.8027
# Epoch 94/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4736.2617 - val_loss: 4561.0933
# Epoch 95/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4731.9878 - val_loss: 4552.4424
# Epoch 96/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4727.3213 - val_loss: 4546.2603
# Epoch 97/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4721.9429 - val_loss: 4545.2334
# Epoch 98/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4717.6226 - val_loss: 4540.5078
# Epoch 99/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4713.0854 - val_loss: 4531.2681
# Epoch 100/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4708.2173 - val_loss: 4532.4033
# Epoch 101/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4702.9756 - val_loss: 4522.0986
# Epoch 102/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4697.5303 - val_loss: 4516.7900
# Epoch 103/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4692.6519 - val_loss: 4508.6826
# Epoch 104/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4687.7402 - val_loss: 4503.9639
# Epoch 105/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4681.6392 - val_loss: 4498.4810
# Epoch 106/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4676.5093 - val_loss: 4496.3037
# Epoch 107/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4672.2534 - val_loss: 4491.5469
# Epoch 108/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4665.4409 - val_loss: 4486.2769
# Epoch 109/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4661.2900 - val_loss: 4471.3979
# Epoch 110/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4656.1108 - val_loss: 4464.0503
# Epoch 111/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4650.4800 - val_loss: 4465.8193
# Epoch 112/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4644.7720 - val_loss: 4459.6504
# Epoch 113/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4638.7471 - val_loss: 4449.3809
# Epoch 114/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4633.2710 - val_loss: 4447.1685
# Epoch 115/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4626.4487 - val_loss: 4440.0269
# Epoch 116/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4621.3638 - val_loss: 4435.4424
# Epoch 117/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4615.5684 - val_loss: 4424.3389
# Epoch 118/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4611.3784 - val_loss: 4426.4639
# Epoch 119/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4605.7021 - val_loss: 4411.5806
# Epoch 120/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4597.8081 - val_loss: 4407.9741
# Epoch 121/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4592.5898 - val_loss: 4406.1904
# Epoch 122/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4586.2686 - val_loss: 4393.9131
# Epoch 123/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4581.0190 - val_loss: 4392.1802
# Epoch 124/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4574.8979 - val_loss: 4378.1411
# Epoch 125/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4568.4097 - val_loss: 4372.2153
# Epoch 126/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4561.9521 - val_loss: 4366.5371
# Epoch 127/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4556.9253 - val_loss: 4356.4619
# Epoch 128/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4550.8457 - val_loss: 4359.9141
# Epoch 129/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4544.3242 - val_loss: 4348.8682
# Epoch 130/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4537.5347 - val_loss: 4339.2949
# Epoch 131/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4532.3394 - val_loss: 4340.4346
# Epoch 132/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4525.0142 - val_loss: 4328.8101
# Epoch 133/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4519.6152 - val_loss: 4326.0776
# Epoch 134/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4511.5210 - val_loss: 4307.8018
# Epoch 135/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4504.8872 - val_loss: 4299.3340
# Epoch 136/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4499.3169 - val_loss: 4302.6162
# Epoch 137/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4491.9082 - val_loss: 4295.2676
# Epoch 138/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4485.3848 - val_loss: 4283.6689
# Epoch 139/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4479.7207 - val_loss: 4275.9512
# Epoch 140/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4472.3271 - val_loss: 4270.5679
# Epoch 141/150
# 27/27 [==============================] - 1s 42ms/step - loss: 4466.2153 - val_loss: 4262.7290
# Epoch 142/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4459.1309 - val_loss: 4260.4531
# Epoch 143/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4453.2441 - val_loss: 4249.4146
# Epoch 144/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4446.2490 - val_loss: 4248.0513
# Epoch 145/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4439.5557 - val_loss: 4236.3442
# Epoch 146/150
# 27/27 [==============================] - 1s 40ms/step - loss: 4431.5581 - val_loss: 4226.9790
# Epoch 147/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4424.9819 - val_loss: 4223.0127
# Epoch 148/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4417.0430 - val_loss: 4214.1841
# Epoch 149/150
# 27/27 [==============================] - 1s 41ms/step - loss: 4410.6865 - val_loss: 4210.2046
# Epoch 150/150
# 27/27 [==============================] - 1s 51ms/step - loss: 4403.8540 - val_loss: 4188.6191

# %%
from tensorflow.keras.preprocessing import image

def load_and_preprocess_image(img_path, target_size=(224, 224)):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # normalize to [0,1]
    img_array = np.expand_dims(img_array, axis=0)  # model.predict expects a batch of images
    return img_array

# %%
def get_ground_truth_pose_for_image(image_filename, json_path):
    """
    Retrieve the ground truth 6DoF pose for a given image from the LineMOD dataset.

    Parameters:
    - image_filename: The filename of the image, e.g., '000123.jpg'.
    - json_path: Path to the scene_gt.json file for the corresponding scene.

    Returns:
    - pose: A dictionary containing the ground truth pose (rotation and translation).
    """

    # Extract image ID from the filename
    image_id = int(image_filename.split('.')[0])

    # Load the JSON data
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Extract pose for the given image ID
    pose_data = data[str(image_id)][0]  # Assuming one primary object per image in LineMOD
    rotation_matrix = pose_data['cam_R_m2c']
    translation_vector = pose_data['cam_t_m2c']

    pose = {
        'rotation': rotation_matrix,
        'translation': translation_vector
    }

    return pose
import numpy as np
from scipy.spatial.transform import Rotation

def dict_to_7d_format(pose_dict):
    """
    Convert a dictionary with 'rotation' and 'translation' keys to a 7D array format:
    [tx, ty, tz, qx, qy, qz, qw].
    """
    R = np.array(pose_dict['rotation']).reshape(3, 3)  # Convert rotation list to a 3x3 matrix.

    # Convert the rotation matrix to a quaternion.
    rotation = Rotation.from_matrix(R)
    quaternion = rotation.as_quat()

    # Combine translation and quaternion into a single array.
    pose_7d = np.concatenate([pose_dict['translation'], quaternion])

    return pose_7d
import numpy as np

def pose_error(gt_pose, pred_pose):
    """
    Calculate and print the translation and rotation error between a ground truth pose and a predicted pose.

    Parameters:
    - gt_pose: Ground truth pose as a 7D array [tx, ty, tz, qx, qy, qz, qw].
    - pred_pose: Predicted pose as a 7D array [tx, ty, tz, qx, qy, qz, qw].
    """

    # Translation error
    trans_error = np.linalg.norm(gt_pose[:3] - pred_pose[:3])

    # Rotation error
    q_gt = gt_pose[3:]
    q_pred = pred_pose[3:]
    dot_product = np.dot(q_gt, q_pred)

    # Clip to ensure dot_product is within the valid range for arccos
    dot_product = np.clip(dot_product, -1.0, 1.0)

    rotation_error = 2 * np.arccos(np.abs(dot_product))

    #print(f"Translation Error: {trans_error:.4f} units")
    #print(f"Rotation Error: {rotation_error:.4f} radians")

    return trans_error, rotation_error
img_path='test/000001/rgb/000150.png'
img_array = load_and_preprocess_image(img_path)
predicted_6dof = model.predict(img_array)[0]
print(predicted_6dof)
image_filename = '000150.jpg'
json_path = 'test/000001/scene_gt.json'
ground_truth_pose = get_ground_truth_pose_for_image(image_filename, json_path)
ground_truth_pose = dict_to_7d_format(ground_truth_pose)
print(ground_truth_pose)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [-3.6818153e+01  4.2227054e+00  8.8183917e+02  4.8923311e-01
#   4.2052439e-01 -1.0961914e-01  2.7369320e-01]
# [ 2.79832120e+01  1.61767631e+00  8.69436480e+02  7.24655619e-01
#   5.35102823e-01 -2.17892054e-01  3.75582556e-01]

# %%
trans_error, rot_error = pose_error(ground_truth_pose, predicted_6dof)

# %%
model.save('drive/MyDrive/trainable_pose/model.h5')
model.save('drive/MyDrive/trainable_pose/model.keras')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import Model
from keras.layers import Input, Dense, Dropout, Concatenate, Flatten
from keras.applications import ResNet50

def pose_refinement_network(input_shape=(224, 224, 3)):
    # Initial pose input (7D: [tx, ty, tz, qx, qy, qz, qw])
    initial_pose_input = Input(shape=(7,), name="initial_pose")

    # RGB Image input
    image_input = Input(shape=input_shape, name="image_input")
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
    for layer in base_model.layers:
        layer.trainable = False
    image_features = base_model(image_input)
    image_features = Flatten()(image_features)

    # Concatenate image features and initial pose
    x = Concatenate()([image_features, initial_pose_input])

    # Dense layers for refinement
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)

    # Output layer for refined pose
    refined_pose = Dense(7, name="refined_pose")(x)

    model = Model(inputs=[image_input, initial_pose_input], outputs=refined_pose)

    return model

# %%
# Predict the initial poses using the trained regression model
initial_train_poses = model.predict(X_train)
initial_val_poses = model.predict(X_val)
initial_test_poses = model.predict(X_test)

# Create and compile the pose refinement network
refinement_model = pose_refinement_network()
refinement_model.compile(optimizer='adam', loss='mse')

# Train the refinement model
refinement_history = refinement_model.fit([X_train, initial_train_poses], y_train_quat,
                                         validation_data=([X_val, initial_val_poses], y_val_quat),
                                         epochs=50, batch_size=64)

# Optionally, evaluate the refinement model
final_test_predictions = refinement_model.predict([X_test, initial_test_poses])
# Out:
# 27/27 [==============================] - 1s 29ms/step
# 6/6 [==============================] - 0s 28ms/step
# 6/6 [==============================] - 0s 28ms/step
# Epoch 1/50
# 14/14 [==============================] - 7s 214ms/step - loss: 39766.2227 - val_loss: 6930.0962
# Epoch 2/50
# 14/14 [==============================] - 1s 83ms/step - loss: 9895.1338 - val_loss: 5357.9077
# Epoch 3/50
# 14/14 [==============================] - 1s 82ms/step - loss: 6613.3320 - val_loss: 4153.2666
# Epoch 4/50
# 14/14 [==============================] - 1s 83ms/step - loss: 5681.1948 - val_loss: 3597.1472
# Epoch 5/50
# 14/14 [==============================] - 1s 83ms/step - loss: 4986.3403 - val_loss: 3206.5779
# Epoch 6/50
# 14/14 [==============================] - 1s 83ms/step - loss: 4788.3066 - val_loss: 2824.9949
# Epoch 7/50
# 14/14 [==============================] - 1s 82ms/step - loss: 4291.7314 - val_loss: 2586.7090
# Epoch 8/50
# 14/14 [==============================] - 1s 82ms/step - loss: 4216.4629 - val_loss: 2513.0481
# Epoch 9/50
# 14/14 [==============================] - 1s 83ms/step - loss: 3888.8301 - val_loss: 2379.7493
# Epoch 10/50
# 14/14 [==============================] - 1s 83ms/step - loss: 3556.7009 - val_loss: 2347.9062
# Epoch 11/50
# 14/14 [==============================] - 1s 83ms/step - loss: 3476.7766 - val_loss: 2154.0391
# Epoch 12/50
# 14/14 [==============================] - 1s 83ms/step - loss: 3404.5952 - val_loss: 2082.9985
# Epoch 13/50
# 14/14 [==============================] - 1s 83ms/step - loss: 3283.4058 - val_loss: 2011.6487
# Epoch 14/50
# 14/14 [==============================] - 1s 83ms/step - loss: 3146.3069 - val_loss: 1963.8376
# Epoch 15/50
# 14/14 [==============================] - 1s 83ms/step - loss: 3113.9377 - val_loss: 1798.1599
# Epoch 16/50
# 14/14 [==============================] - 1s 82ms/step - loss: 3090.4028 - val_loss: 1672.0405
# Epoch 17/50
# 14/14 [==============================] - 1s 82ms/step - loss: 2862.1252 - val_loss: 1585.8254
# Epoch 18/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2850.6785 - val_loss: 1531.2983
# Epoch 19/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2699.4106 - val_loss: 1403.3553
# Epoch 20/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2526.8406 - val_loss: 1394.3046
# Epoch 21/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2579.6113 - val_loss: 1305.7595
# Epoch 22/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2493.8096 - val_loss: 1480.1512
# Epoch 23/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2485.8589 - val_loss: 1262.2178
# Epoch 24/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2209.4607 - val_loss: 1222.4562
# Epoch 25/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2298.8318 - val_loss: 1137.2118
# Epoch 26/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2187.6597 - val_loss: 1181.7988
# Epoch 27/50
# 14/14 [==============================] - 1s 86ms/step - loss: 2303.3088 - val_loss: 1028.6191
# Epoch 28/50
# 14/14 [==============================] - 1s 82ms/step - loss: 2199.8745 - val_loss: 1006.7120
# Epoch 29/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2282.9409 - val_loss: 1048.8402
# Epoch 30/50
# 14/14 [==============================] - 1s 82ms/step - loss: 2367.9270 - val_loss: 1072.1730
# Epoch 31/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2141.0029 - val_loss: 1406.4524
# Epoch 32/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2190.6060 - val_loss: 1083.5497
# Epoch 33/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2066.8369 - val_loss: 927.5350
# Epoch 34/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2031.8114 - val_loss: 834.0802
# Epoch 35/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2076.4624 - val_loss: 920.5723
# Epoch 36/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2246.8875 - val_loss: 960.5859
# Epoch 37/50
# 14/14 [==============================] - 1s 84ms/step - loss: 2418.8108 - val_loss: 1169.0892
# Epoch 38/50
# 14/14 [==============================] - 1s 82ms/step - loss: 2046.6232 - val_loss: 1198.8586
# Epoch 39/50
# 14/14 [==============================] - 1s 83ms/step - loss: 2013.0923 - val_loss: 1071.7170
# Epoch 40/50
# 14/14 [==============================] - 1s 83ms/step - loss: 1908.6102 - val_loss: 1008.7001
# Epoch 41/50
# 14/14 [==============================] - 1s 84ms/step - loss: 1964.3967 - val_loss: 866.0561
# Epoch 42/50
# 14/14 [==============================] - 1s 84ms/step - loss: 1956.3024 - val_loss: 931.4259
# Epoch 43/50
# 14/14 [==============================] - 1s 84ms/step - loss: 1967.6072 - val_loss: 1752.1115
# Epoch 44/50
# 14/14 [==============================] - 1s 83ms/step - loss: 1960.6144 - val_loss: 1356.6749
# Epoch 45/50
# 14/14 [==============================] - 1s 84ms/step - loss: 1835.1787 - val_loss: 993.1561
# Epoch 46/50
# 14/14 [==============================] - 1s 83ms/step - loss: 1989.9092 - val_loss: 1084.6676
# Epoch 47/50
# 14/14 [==============================] - 1s 82ms/step - loss: 1843.3828 - val_loss: 1374.8763
# Epoch 48/50
# 14/14 [==============================] - 1s 84ms/step - loss: 1921.3348 - val_loss: 1918.7146
# Epoch 49/50
# 14/14 [==============================] - 1s 84ms/step - loss: 1813.5308 - val_loss: 1336.7303
# Epoch 50/50
# 14/14 [==============================] - 1s 83ms/step - loss: 1721.9072 - val_loss: 849.4607
# 6/6 [==============================] - 1s 33ms/step

# %%
# Predict poses on the test set
y_pred_quat = model.predict(X_test)
y_pred_quat = refinement_model.predict([X_test,y_pred_quat])
# Initialize lists to store errors
trans_errors = []
rot_errors = []

# Compute errors for each prediction against the ground truth
for gt_pose, pred_pose in zip(y_test_quat, y_pred_quat):
    trans_error, rot_error = pose_error(gt_pose, pred_pose)
    trans_errors.append(trans_error)
    rot_errors.append(rot_error)

# Convert lists to numpy arrays for further analysis
trans_errors = np.array(trans_errors)
rot_errors = np.array(rot_errors)

# Report overall mean and standard deviation for both translation and rotation errors
print(f"Mean Translation Error: {trans_errors.mean():.4f} units")
print(f"Standard Deviation of Translation Error: {trans_errors.std():.4f} units")
print(f"Mean Rotation Error: {rot_errors.mean():.4f} radians")
print(f"Standard Deviation of Rotation Error: {rot_errors.std():.4f} radians")
# Out:
# 6/6 [==============================] - 0s 30ms/step
# 6/6 [==============================] - 0s 33ms/step
# Mean Translation Error: 79.5654 units
# Standard Deviation of Translation Error: 42.2922 units
# Mean Rotation Error: 0.3119 radians
# Standard Deviation of Rotation Error: 0.7801 radians

# %%
refinement_model.save('drive/MyDrive/trainable_pose/refinement_model.h5')
refinement_model.save('drive/MyDrive/trainable_pose/refinement_model.keras')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
